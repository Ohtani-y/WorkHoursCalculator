# %% [markdown]
# ### データフレーム作成

# %%
import openpyxl
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Border, Side

df_project = pd.read_excel("../プロジェクト実績集計（社員・日々）.xlsx", usecols=range(7))
df_sum1 = pd.read_excel("../月次合計一覧 (1).xlsx", usecols=range(7))
df_sum2 = pd.read_excel("../月次合計一覧.xlsx", usecols=range(21))
# Out:
# D:\soft\Anaconda3\envs\main\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_sum2
# Out:
#    就労所属コード 就労所属名称   社員番号                社員名称  所定労働時間 フレックス\n総労働時間   残業時間  \
# 0     L00L  開発管理部  87002               大谷　義信     対象外       168:55    対象外
# 1     L00N  開発管理課  83011               立川　義彦  152:00          対象外   0:00
# 2     L00N  開発管理課  90060               高田　康秀     対象外       200:00    対象外
# 3     L00N  開発管理課  90089               川島　義仁     対象外       168:30    対象外
# 4     L00N  開発管理課  A0035               山下　雅也     対象外       186:30    対象外
# 5     L00N  開発管理課  FC029               塩村　晴美  160:00          対象外   0:00
# 6     L00N  開発管理課  FN001  スミオ　エリック　ジョン　パシコラン  160:00          対象外  11:15
# 7     L00N  開発管理課  FT006               田村　美香  160:00          対象外   0:00
# 8     L00N  開発管理課  FT009               山本　凌平  160:00          対象外   0:00
# 9     L00N  開発管理課  GJ003          チャン　ティ　イエン  152:00          対象外  21:15
# 10    L00N  開発管理課  GP009              園杭　なつ美  152:00          対象外   0:00
# 11    L00N  開発管理課  GQ001               生田　千尋  152:00          対象外  18:15
# 12    L00N  開発管理課  GR001               浦上　大希  130:30          対象外   0:00
# 13    L00N  開発管理課  GR003               生駒　憲一  160:00          対象外   3:00
# 14    L00N  開発管理課  NC095               千原　ユキ  160:00          対象外   1:00
# 15    L00N  開発管理課  NC101          ナカザワ　ガブリエラ  160:00          対象外   1:00
# 16    L00N  開発管理課  NC103            カワッ　ジェシカ  160:00          対象外   1:00
# 17    L00N  開発管理課  ZV001               内田　祐介  160:00          対象外   0:00
# 18    L00P   ＣＡＥ課  B0057               小田　宇大     対象外       193:20    対象外
# 19    L00P   ＣＡＥ課  B0058               藤岡　まみ  112:00          対象外   0:00
# 20    L00P   ＣＡＥ課  B5031               永野　直哉     対象外       185:45    対象外
# 21    L00P   ＣＡＥ課  B6035               野口　知葉     対象外       171:45    対象外
# 22    L00P   ＣＡＥ課  B7040               木下　佳典     対象外       192:10    対象外
# 23    L00P   ＣＡＥ課  C3032               岩口　枝央     対象外       172:50    対象外
# 24    L00Q  実験研究課  82043               松本　光之  160:00          対象外   0:00
# 25    L00Q  実験研究課  84035               田中　康彦  159:00          対象外   0:00
# 26    L00Q  実験研究課  85104               脇本　和弘  160:00          対象外   3:00
# 27    L00Q  実験研究課  86027               上林　弘孝  160:00          対象外  19:00
# 28    L00Q  実験研究課  89133               今岡　照雅  160:00          対象外  18:00
# 29    L00Q  実験研究課  94006               桒田　考則     対象外       190:00    対象外
# 30    L00Q  実験研究課  95003               小野　博朗     対象外       160:00    対象外
# 31    L00Q  実験研究課  99053               草山　綾子  151:20          対象外   0:00
# 32    L00Q  実験研究課  B2023              古川　奈津美  136:00          対象外  25:00
# 33    L00Q  実験研究課  B6026               岩永　拓也  160:00          対象外  18:00
# 34    L00Q  実験研究課  B9057               河口　駿太  150:00          対象外  34:00
# 35    L00Q  実験研究課  GB015                平尾　亮  145:45          対象外   1:00
# 36    L00R    知財課  A6024               井場　麻美  135:00          対象外   0:00
# 37    L00R    知財課  A7022              佐々木　偉子    0:00          対象外   0:00
# 38    L00R    知財課  A9054               日高　勇樹  152:00          対象外   5:00
# 39    L00R    知財課  B8054               的場　千絵     対象外       163:15    対象外
# 40    L00R    知財課  B8120              中須賀　大悟  160:00          対象外   8:00
# 41    L00R    知財課  B8132              金山光　直諒     対象外       173:00    対象外
# 42    L00R    知財課  C0095               宮部　智子  143:00          対象外   0:00
#
#    フレックス\n超過時間 所定休日出勤時間 法定休日出勤時間  ...    減時間 フレックス\n不足時間 遅刻回数  早退回数  私用外出回数  \
# 0         8:55     0:00     0:00  ...    対象外        0:00    0     0       0
# 1          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 2        40:00     0:00     0:00  ...    対象外        0:00    0     0       0
# 3         8:30     0:00     0:00  ...    対象外        0:00    0     0       0
# 4        26:30     0:00     0:00  ...    対象外        0:00    0     0       0
# 5          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 6          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 7          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 8          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 9          対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 10         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 11         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 12         対象外     0:00     0:00  ...   5:30         対象外    0     1       0
# 13         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 14         対象外     4:45     0:00  ...   0:00         対象外    0     0       0
# 15         対象外    11:15     0:00  ...   0:00         対象外    0     0       0
# 16         対象外    11:15     0:00  ...   0:00         対象外    0     0       0
# 17         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 18       33:20     0:00     0:00  ...    対象外        0:00    0     0       0
# 19         対象外     0:00     0:00  ...  40:00         対象外    0     0       0
# 20       25:45     0:00     0:00  ...    対象外        0:00    0     0       0
# 21       11:45     0:00     0:00  ...    対象外        0:00    0     0       0
# 22       32:10     0:00     0:00  ...    対象外        0:00    0     0       0
# 23       12:50     0:00     0:00  ...    対象外        0:00    0     0       0
# 24         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 25         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 26         対象外     3:40     0:00  ...   0:00         対象外    0     0       0
# 27         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 28         対象外    14:00     0:00  ...   0:00         対象外    0     0       0
# 29       30:00     0:00     0:00  ...    対象外        0:00    0     0       0
# 30        0:00     0:00     0:00  ...    対象外        0:00    0     0       0
# 31         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 32         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 33         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 34         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 35         対象外     0:00     0:00  ...   6:15         対象外    0     1       0
# 36         対象外     5:00     4:00  ...  22:00         対象外    0     0       0
# 37         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 38         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 39        3:15     0:00     0:00  ...    対象外        0:00    0     0       0
# 40         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
# 41       13:00     0:00     0:00  ...    対象外        0:00    0     0       0
# 42         対象外     0:00     0:00  ...   0:00         対象外    0     0       0
#
#     宿直回数  出向回数  夜勤回数  テレワーク回数  不就業時間
# 0      0     0     0        0   0:00
# 1      0     0     0        0   0:00
# 2      0     0     0        0   0:00
# 3      0     0     0        0   0:00
# 4      0     0     0        0   0:00
# 5      0     0     0        0   0:00
# 6      0     0     0        0   0:00
# 7      0     0     0        0   0:00
# 8      0     0     0        0   0:00
# 9      0     0     0        0   0:00
# 10     0     0     0        0   0:00
# 11     0     0     0        0   0:00
# 12     0     0     0        0   0:00
# 13     0     0     0        0   0:00
# 14     0     0     0        0   0:00
# 15     0     0     0        0   0:00
# 16     0     0     0        0   0:00
# 17     0     0     0        0   0:00
# 18     0     0     0        0   0:00
# 19     0     0     0        0   0:00
# 20     0     0     0        0   0:00
# 21     0     0     0        0   0:00
# 22     0     0     0        0   0:00
# 23     0     0     0        0   0:00
# 24     0     0     0        0   0:00
# 25     0     0     0        0   0:00
# 26     0     0     0        0   0:00
# 27     0     0     0        0   0:00
# 28     0     0     0        0   0:00
# 29     0     0     0        0   0:00
# 30     0     0     0        0   0:00
# 31     0     0     0        0   0:00
# 32     0     0     0        0   0:00
# 33     0     0     0        0   0:00
# 34     0     0     0        0   0:00
# 35     0     0     0        0   0:00
# 36     0     0     0        4   0:00
# 37     0     0     0        0   0:00
# 38     0     0     0       14   0:00
# 39     0     0     0       11   0:00
# 40     0     0     0        0   0:00
# 41     0     0     0        1   0:00
# 42     0     0     0        1   0:00
#
# [43 rows x 21 columns]

# %% [markdown]
# #### チェック用ダミーデータ作成と追加

# %%
# ダミーデータの追加
dummy_data = {
    "就労所属コード": ["L00X"],
    "就労所属名称": ["テスト部"],
    "社員番号": ["T0001"],
    "社員名称": ["テスト　太郎"],
    "総労働時間": ["190:00"],
    "月の法定限度時間": ["177:00"],
    "安衛法超過時間": ["13:00"],
}

df_dummy = pd.DataFrame(dummy_data)

df_sum1 = df_sum1.append(df_dummy, ignore_index=True)

# ダミーデータの追加
dummy_data2 = {
    "就労所属コード": ["L00X"],
    "就労所属名称": ["テスト部"],
    "社員番号": ["T0002"],
    "社員名称": ["テスト　花子"],
    "総労働時間": ["240:00"],
    "月の法定限度時間": ["177:00"],
    "安衛法超過時間": ["63:00"],
}

df_dummy = pd.DataFrame(dummy_data2)

df_sum1 = df_sum1.append(df_dummy, ignore_index=True)
# Out:
# C:\Users\yamamoto-r\AppData\Local\Temp\ipykernel_23028\3536048256.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sum1 = df_sum1.append(df_dummy, ignore_index=True)
# C:\Users\yamamoto-r\AppData\Local\Temp\ipykernel_23028\3536048256.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sum1 = df_sum1.append(df_dummy, ignore_index=True)

# %%
df_sum1
# Out:
#    就労所属コード 就労所属名称   社員番号                社員名称   総労働時間 月の法定限度時間 安衛法超過時間
# 0     L00L  開発管理部  87002               大谷　義信   92:20   177:00    0:00
# 1     L00N  開発管理課  83011               立川　義彦   72:00   177:00    0:00
# 2     L00N  開発管理課  90060               高田　康秀  105:50   177:00    0:00
# 3     L00N  開発管理課  90089               川島　義仁   66:00   177:00    0:00
# 4     L00N  開発管理課  A0035               山下　雅也   91:25   177:00    0:00
# 5     L00N  開発管理課  FC029               塩村　晴美   86:00   177:00    0:00
# 6     L00N  開発管理課  FC030               河野　和也   88:00   177:00    0:00
# 7     L00N  開発管理課  FN001  スミオ　エリック　ジョン　パシコラン   83:00   177:00    0:00
# 8     L00N  開発管理課  FT006               田村　美香   92:30   177:00    0:00
# 9     L00N  開発管理課  FT009               山本　凌平   80:00   177:00    0:00
# 10    L00N  開発管理課  GJ003          チャン　ティ　イエン   87:15   177:00    0:00
# 11    L00N  開発管理課  GP009              園杭　なつ美   48:30   177:00    0:00
# 12    L00N  開発管理課  GQ001               生田　千尋  103:15   177:00    0:00
# 13    L00N  開発管理課  GR001               浦上　大希   84:15   177:00    0:00
# 14    L00N  開発管理課  GR003               生駒　憲一   88:00   177:00    0:00
# 15    L00N  開発管理課  NC101          ナカザワ　ガブリエラ   83:20   177:00    0:00
# 16    L00N  開発管理課  NC103            カワッ　ジェシカ  100:50   177:00    0:00
# 17    L00N  開発管理課  NC108            クウカ　ミシェレ   66:20   177:00    0:00
# 18    L00N  開発管理課  ZV001               内田　祐介   97:00   177:00    0:00
# 19    L00P   ＣＡＥ課  B0057               小田　宇大  108:10   177:00    0:00
# 20    L00P   ＣＡＥ課  B0058               藤岡　まみ   57:00   177:00    0:00
# 21    L00P   ＣＡＥ課  B5031               永野　直哉   87:15   177:00    0:00
# 22    L00P   ＣＡＥ課  B6035               野口　知葉   81:10   177:00    0:00
# 23    L00P   ＣＡＥ課  B7040               木下　佳典  107:50   177:00    0:00
# 24    L00P   ＣＡＥ課  C3032               岩口　枝央  102:25   177:00    0:00
# 25    L00Q  実験研究課  82043               松本　光之   96:00   177:00    0:00
# 26    L00Q  実験研究課  84035               田中　康彦   83:40   177:00    0:00
# 27    L00Q  実験研究課  85104               脇本　和弘   99:00   177:00    0:00
# 28    L00Q  実験研究課  86027               上林　弘孝  103:40   177:00    0:00
# 29    L00Q  実験研究課  89133               今岡　照雅   94:30   177:00    0:00
# 30    L00Q  実験研究課  94006               桒田　考則  107:45   177:00    0:00
# 31    L00Q  実験研究課  95003               小野　博朗   80:00   177:00    0:00
# 32    L00Q  実験研究課  99053               草山　綾子   91:40   177:00    0:00
# 33    L00Q  実験研究課  B2023              古川　奈津美   81:30   177:00    0:00
# 34    L00Q  実験研究課  B6026               岩永　拓也   91:10   177:00    0:00
# 35    L00Q  実験研究課  B9057               河口　駿太   85:00   177:00    0:00
# 36    L00Q  実験研究課  GB015                平尾　亮   82:00   177:00    0:00
# 37    L00R    知財課  A6024               井場　麻美   56:05   177:00    0:00
# 38    L00R    知財課  A7022              佐々木　偉子    0:00   177:00    0:00
# 39    L00R    知財課  A9054               日高　勇樹   96:00   177:00    0:00
# 40    L00R    知財課  B8054               的場　千絵   92:10   177:00    0:00
# 41    L00R    知財課  B8120              中須賀　大悟   86:00   177:00    0:00
# 42    L00R    知財課  B8132              金山光　直諒   53:30   177:00    0:00
# 43    L00R    知財課  C0095               宮部　智子   81:50   177:00    0:00
# 44    L00X   テスト部  T0001              テスト　太郎  190:00   177:00   13:00
# 45    L00X   テスト部  T0002              テスト　花子  240:00   177:00   63:00

# %% [markdown]
# #### 時間を変換するための関数

# %%
# 時間に変換するための関数
def time_to_minutes(time):
    h, m = map(int, time.split(":"))
    return h * 60 + m


# 分を時間に変換するための関数
def minutes_to_time(minutes):
    h = minutes // 60
    m = minutes % 60
    return f"{h}:{m:02d}"

# %% [markdown]
# ### 超過時間チェック関数

# %% [markdown]
# 引数は読み込んだデータフレーム
#
# ~~総労働時間と月の法定限度時間を対象に超過時間を算出~~
# 安衛法超過時間を参照して行を取り出す
#
# ~~超過時間が発生した行を取り出す~~

# %%
# 月次合計一覧から労働時間の超過を算出
def overworkcheck(df):
    # 超過している行を抽出
    overtime_df = df[df["安衛法超過時間"].apply(time_to_minutes) > 0]

    # 必要な列を表示
    return overtime_df[
        ["就労所属コード", "就労所属名称", "社員番号", "社員名称", "総労働時間", "月の法定限度時間", "安衛法超過時間"]
    ]

# %%
# 関数の実行
overtime_df = overworkcheck(df_sum1)

# %%
overtime_df
# Out:
#    就労所属コード 就労所属名称   社員番号    社員名称   総労働時間 月の法定限度時間 安衛法超過時間
# 44    L00X   テスト部  T0001  テスト　太郎  190:00   177:00   13:00
# 45    L00X   テスト部  T0002  テスト　花子  240:00   177:00   63:00

# %% [markdown]
# ### 時間超過している個人の情報をExcelに書き込む

# %%
def get_overtime_hours(df_sum1, df_sum2):
    # 社員名称をキーにしてdf_sum2から残業時間またはフレックス超過時間を取得
    def find_overtime(row):
        employee_name = row["社員名称"]
        matched_row = df_sum2[df_sum2["社員名称"] == employee_name]
        if matched_row.empty:
            return ""
        overtime = matched_row.iloc[0]["残業時間"]
        flex_overtime = matched_row.iloc[0]["フレックス\n超過時間"]
        if overtime != "対象外":
            hours, _ = map(int, overtime.split(":"))
            return f"{hours}h"
        elif flex_overtime != "対象外":
            hours, _ = map(int, flex_overtime.split(":"))
            return f"{hours}h"
        return ""

    df_sum1["今月の残業時間"] = df_sum1.apply(find_overtime, axis=1)
    return df_sum1
    
def write_overtime_to_excel(df, file_name="../result/result.xlsx", start_cell="C6"):
    
    # Excelファイル読み込み
    wb = load_workbook("../ref/残業申請サンプル.xlsx")
    ws = wb.active

    # 引数のセル番号を行番号と列番号に変換
    start_row, start_col = openpyxl.utils.cell.coordinate_to_tuple(start_cell)

    count = 0  # カウントの初期化

    # データを書き込む
    for row_idx, (_, row) in enumerate(df.iterrows(), start=start_row):
        ws.cell(row=row_idx, column=start_col, value=row["社員名称"])
        ws.cell(row=row_idx, column=start_col + 2, value=row["就労所属名称"])
        ws.cell(row=row_idx + start_row, column=start_col + 3, value=row["今月の残業時間"])

        # Merge cells for "主な業務内容" in the data rows
        ws.merge_cells(
            start_row=row_idx,
            start_column=start_col + 6,
            end_row=row_idx,
            end_column=start_col + 7,
        )
        if count > 0:
            count += 1  # 2つ目以降の場合、カウントをインクリメント

        if count == 0:
            count += 1  # 初回処理後にカウントを1に設定

    # 罫線で表を作る
    rows = len(df)  # 行の数
    cols = 7  # 列の数
    thin_border = Border(
        left=Side(style="thin"),
        right=Side(style="thin"),
        top=Side(style="thin"),
        bottom=Side(style="thin"),
    )

    for row in ws.iter_rows(
        min_row=start_row,
        max_row=start_row + rows - 1,
        min_col=start_col,
        max_col=start_col + cols - 1,
    ):
        for cell in row:
            cell.border = thin_border

    # ファイルを保存
    wb.save(file_name)

# %%
filename = "../ref/test.xlsx"  # 書き込むファイル名
start_cell = "C6"  # 書き込むスタート位置

overtime_df = get_overtime_hours(overtime_df, df_sum2)
write_overtime_to_excel(overtime_df, filename, start_cell)

# %% [markdown]
# ### 月次合計一覧から、フレックスを含む残業時間を合算する関数
#
# 月次合計一覧のデータフレーム df_sum2 を使用

# %%
# 残業時間とフレックス超過時間の列を変換し、合計を合算
def convert_to_minutes(time):
    if "対象外" in time or not time:
        return 0

    # "HH:MM:SS" 形式も "HH:MM"形式も考慮
    parts = time.split(":")
    if len(parts) == 3:
        h, m, s = map(int, parts)
    elif len(parts) == 2:
        h, m = map(int, parts)
        s = 0
    else:
        return 0

    return h * 60 + m


# 合計残業時間を計算
def calculate_total_time(df, columns):
    total_minutes = sum(df[col].apply(convert_to_minutes).sum() for col in columns)

    return minutes_to_time(total_minutes)

# %%
# 合算する対象の列
columns_to_sum = ["残業時間", "フレックス\n超過時間"]

# 時間を算出する
total_time = calculate_total_time(df_sum2, columns_to_sum)

# 結果の出力
print(total_time)
# Out:
# 433:45

# %% [markdown]
# ### 算出したデータをExcelに出力

# %% [markdown]
# ### Excelへの書き込み自動化関数
#
# 引数は部署名、月
#
# 書き込み保存するところまで関数内で完結させる

# %%
# 書き込むファイルのパス
# 上で個人の情報を書き込んだファイルに追加で書き込む
excel_sample = "../ref/test.xlsx"

# %%
def update_overtime_request(filepath, department, month, data):
    # 部署名と対応する行番号の辞書
    start_col = 19
    department_row_mapping = {
        "本部長付": start_col,
        "開発管理部": start_col + 3,
        "開発推進部": start_col + 6,
        "1開発設計部": start_col + 9,
        "ディバイス開発部": start_col + 12,
        "電気・電子開発部": start_col + 15,
        "開発本部": start_col + 18,
    }
    # 月と対応する列番号の辞書
    month_column_mapping = {
        1: "E",
        2: "F",
        3: "G",
        4: "H",
        5: "I",
        6: "J",
        7: "K",
        8: "L",
        9: "M",
        10: "N",
        11: "O",
        12: "P",
    }

    # 対象の行番号と列番号を取得
    row = department_row_mapping.get(department)
    column = month_column_mapping.get(month)

    if row is None:
        raise ValueError(f"指定された部署名'{department}'が無効です。")
    if column is None:
        raise ValueError(f"指定された月'{month}'が無効です。")

    # Excelファイル読み込み
    wb = load_workbook(filepath)
    ws = wb.active

    # セルにデータを入力
    cell = f"{column}{row}"
    ws[cell] = data

    # ファイルを保存
    wb.save("../result/result.xlsx")

    print("処理完了")

# %%
department = "開発管理部"
month = 6

# 総残業時間total_timeをファイルに書き込む
update_overtime_request(excel_sample, department, month, total_time)
# Out:
# 処理完了
